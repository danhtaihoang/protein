# %%
import direct_info
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
w = np.loadtxt('w2d.txt')
s0 = np.loadtxt('s0.txt')

# %%
di = direct_info.direct_info(s0,w)

# %%
plt.imshow(di,cmap='rainbow',origin='lower')
plt.clim(0,0.1)
plt.colorbar(fraction=0.045, pad=0.05,ticks=[0,0.1])

# %%
np.savetxt('di.txt',di,fmt='%f')

# %%
di.shape
# Out:
# (137, 137)
